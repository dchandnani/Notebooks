# %% [markdown]
# # Mime types

# %%
# Sample text for mimetype text/plain
print("Sample text for mimetype text/plain")
# Out:
# Sample text for mimetype text/plain

# %%
# Sample text for mimetype text/html
from IPython.display import HTML
HTML("<h3>Sample text for mimetype text/html</h3>")
# Out:
# <h3>Sample text for mimetype text/html</h3>

# %%
# Sample text for mimetype text/markdown
# Out:
# # Sample text for mimetype text/markdown
# | Header 1| Header 2|
# |----|----|
# |Item 1|Item 2|
# - bullet 1
# - bullet 2
# *italic* `quoted`
# > Code Block:
# ```python
# # testing comments
# ```

# %%
# Sample text for mimetype text/latex
from IPython.display import Latex
Latex('''The mass-energy equivalence is described by the famous equation

$$E=mc^2$$

discovered in 1905 by Albert Einstein.
In natural units ($c$ = 1), the formula expresses the identity

\\begin{equation}
E=m
\\end{equation}''')
# Out:
# The mass-energy equivalence is described by the famous equation
#
# $$E=mc^2$$
#
# discovered in 1905 by Albert Einstein.
# In natural units ($c$ = 1), the formula expresses the identity
#
# \begin{equation}
# E=m
# \end{equation}

# %%
# Sample text for mimetype application/javascript
var message = 'Sample text for mimetype application/javascript';
console.warn(message);
alert(message);

# %%
# Sample text for mimetype application/json

# %%
# Sample text for mimetype application/vnd.jupyter.widget-view+json

from IPython.display import display
from ipywidgets import widgets

w = widgets.IntSlider()
display(w)

a = widgets.FloatText()
b = widgets.FloatSlider()
display(a,b)


mylink = widgets.jslink((a, 'value'), (b, 'value'))

button = widgets.ToggleButton(
    value=False,
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check' # (FontAwesome names without the `fa-` prefix)
)

checkbox = widgets.Checkbox(
    value=False,
    description='Check me',
    disabled=False,
    indent=False
)

dropdown = widgets.Dropdown(
    options=['1', '2', '3'],
    value='2',
    description='Number:',
    disabled=False,
)

radiobuttons = widgets.RadioButtons(
    options=['pepperoni', 'pineapple', 'anchovies'],
#    value='pineapple', # Defaults to 'pineapple'
#    layout={'width': 'max-content'}, # If the items' names are long
    description='Pizza topping:',
    disabled=False
)

box = widgets.Box(
    [
        widgets.Label(value='Pizza topping with a very long label:'),
        widgets.RadioButtons(
            options=[
                'pepperoni',
                'pineapple',
                'anchovies',
                'and the long name that will fit fine and the long name that will fit fine and the long name that will fit fine '
            ],
            layout={'width': 'max-content'}
        )
    ]
)

select = widgets.Select(
    options=['Linux', 'Windows', 'OSX'],
    value='OSX',
    # rows=10,
    description='OS:',
    disabled=False
)

combobox = widgets.Combobox(
    # value='John',
    placeholder='Choose Someone',
    options=['Paul', 'John', 'George', 'Ringo'],
    description='Combobox:',
    ensure_option=True,
    disabled=False
)

label = widgets.Label(value="The $m$ in $E=mc^2$:")

datepicker = widgets.DatePicker(
    description='Pick a Date',
    disabled=False
)

colorpicker = widgets.ColorPicker(
    concise=False,
    description='Pick a color',
    value='blue',
    disabled=False
)

fileupload = widgets.FileUpload(
    accept='',  # Accepted file extension e.g. '.txt', '.pdf', 'image/*', 'image/*,.pdf'
    multiple=False  # True to accept multiple files upload else False
)

display(button, checkbox, dropdown, radiobuttons, box, select, combobox, label, datepicker, colorpicker, fileupload)
# Out:
# IntSlider(value=0)
# FloatText(value=0.0)
# FloatSlider(value=0.0)
# ToggleButton(value=False, description='Click me', icon='check', tooltip='Description')
# Checkbox(value=False, description='Check me', indent=False)
# Dropdown(description='Number:', index=1, options=('1', '2', '3'), value='2')
# RadioButtons(description='Pizza topping:', options=('pepperoni', 'pineapple', 'anchovies'), value='pepperoni')
# Box(children=(Label(value='Pizza topping with a very long label:'), RadioButtons(layout=Layout(width='max-cont…
# Select(description='OS:', index=2, options=('Linux', 'Windows', 'OSX'), value='OSX')
# Combobox(value='', description='Combobox:', ensure_option=True, options=('Paul', 'John', 'George', 'Ringo'), p…
# Label(value='The $m$ in $E=mc^2$:')
# DatePicker(value=None, description='Pick a Date')
# ColorPicker(value='blue', description='Pick a color')
# FileUpload(value={}, description='Upload')

# %%
# Sample text for mimetype application/geo+json

# %%
# Sample text for mimetype application/vnd.plotly.v1+json

# %%
# Sample text for mimetype application/vnd.dataresource+json

# %%
# Sample text for mimetype application/vdom.v1+json
from IPython.display import display
display(
    {
        'application/vdom.v1+json': {
            'tagName': 'marquee',
            'attributes': {
            },
            'children': 'Sample text for mimetype application/vdom.v1+json',
        }
    },
    raw=True
)

# %%
# Sample text for mimetype image/svg+xml
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
t = np.linspace(0, 20, 500)

plt.plot(t, np.sin(t))
plt.show()

# %%
# Sample text for mimetype image/gif

# %%
# Sample text for mimetype image/png
from IPython.display import Image
Image('http://jakevdp.github.com/figures/xkcd_version.png')

# %%
# Sample text for mimetype image/jpeg
