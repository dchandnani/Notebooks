# %% [markdown]
# # Ext-A Chars
#
# ①Ⅻㄨㄩ 啊阿鼾齄丂丄狚狛狜狝﨨﨩ˊˋ˙–⿻〇㐀㐁䶴䶵U1[]U2[]U3[

# %% [markdown]
# # Ext-B Chars
#
#
# (Ext-B, Mongolia, Tibetan, Uyghur, Yi, Dehong Dai, Xishuangbanna Dai):
#
# 𠀀𠀁𪛕𪛖
#
# ᠮᠣᠩᠭᠣᠯ ᠦᠰᠦᠭ བོད་ཡིག ۋېڭكقق ھس قك كدسدق د ꆈꌠꁱꂷ
#
# ᥘᥣᥭᥰ ᥖᥭᥰ ᥖᥬᥲᥑᥨᥒᥰ ᦎᦷᦑᦺᦖᦺᧈᦉᦲᧇᦉᦸᧂᦗᧃᦓᦱ

# %%
(CJK + Ext-A char)


①Ⅻㄨㄩ 啊阿鼾齄丂丄狚狛狜狝﨨﨩ˊˋ˙–⿻〇㐀㐁䶴䶵U1[]U2[]U3[

# %%
(Ext-B, Mongolia, Tibetan, Uyghur, Yi, Dehong Dai, Xishuangbanna Dai):

𠀀𠀁𪛕𪛖

ᠮᠣᠩᠭᠣᠯ ᠦᠰᠦᠭ བོད་ཡིག ۋېڭكقق ھس قك كدسدق د ꆈꌠꁱꂷ

ᥘᥣᥭᥰ ᥖᥭᥰ ᥖᥬᥲᥑᥨᥒᥰ ᦎᦷᦑᦺᦖᦺᧈᦉᦲᧇᦉᦸᧂᦗᧃᦓᦱ

# %%
Mandatory for Compliance
Single byte
Ⅻㄨㄩ
!"#)6=@Aa}~

Four byte
Four byte: Ext-A 㐀㒣㕴㕵㙉㙊䵯䵰䶴䶵 (Unicode 3.0)
Four byte: Ext-B 𠀀𠀁𠀂𠀃𪛑𪛒𪛓𪛔𪛕𪛖

Required for Full Compliance (not blocking)
Double byte
(with three PUA characters replaced ‘9’ and non-PUA equivalents moved as follows: ḿ inserted after 1st character; 龹龻 moved to new ‘Double byte Unicode 4.1’ string)

啊ḿ齄丂狛狜隣郎隣兀﨩ˊ▇█〞〡￤℡㈱‐ー﹡﹢﹫、〓ⅰⅹ⒈€㈠㈩ⅠⅫ！￣ぁんァヶΑ︴АЯаяāɡㄅㄩ─╋︵﹄︻︱︳︴ⅰⅹɑ9ɡ〇〾⿻⺁9䜣9€

Double byte Unicode 4.1
龹龻

Double byte Private Use Area
(PUA, extracted from the above string, because while it is desirable to have these work, it is not must have for GB18030 certification)

 (Unicode 3.1)
Four byte: Mongolian ᠀᠐᠙ᠠᡷᢀᡨᡩᡪᡫ
Four byte: Tibetan ༀཇཉཪཱྋ྾࿌࿏ྼྙ
Four byte: Yi ꀀꒌꂋꂌꂍꂎꂔꂕ꒐꓆
Four byte: Uighur ،؟ئبتجدرشعەﭖﭙﯓﯿﺉﺒﻺﻼ
Four byte: Tai Le ᥐᥥᥦᥧᥨᥭᥰᥱᥲᥴ
Four byte: Hangul ᄓᄕᇬᇌᇜᇱㄱㅣ가힝
